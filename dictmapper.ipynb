# %%
import json
# Expect: list of json objects.
import re
import typing

class MapperLocation:
    def __init__(self, location, column_name, coalesce_value=None, fail_if_missing=False, attempt_json_serializing=True, delimiter='::',  convert_func=None):
        self.location = location
        self.column_name = column_name
        self.coalesce_value=coalesce_value
        self.fail_if_missing=fail_if_missing
        self.attempt_json_serializing=True,
        self.delimiter=delimiter
        self.convert_func=convert_func
        
class RequiredElementMissingError(AttributeError):
    pass

class DictMapper:
    def __init__(self, in_dict: list, mapper: dict) -> None:
        self.in_dict = in_dict
        self.mapper = mapper
        self.table_names = [key for key in mapper]

        self.re_check_list_base_location = r"^.+(?=\[\])"
        self.re_check_list_specific_element = r"[a-zA-Z]+\[[0-9]+\]"
        self.re_check_list_unlimited_element = r"[a-zA-Z]+(?=\[\])"
        self.re_list_location_name = r"[a-zA-Z]+(?=\[)"
        self.re_list_location_index = r"(?<=\[)[0-9]+(?=\])"


    def get_records(self, table_name: str=None, extra_data=None) -> typing.Generator:
        if extra_data is None:
            extra_data = {}

        if table_name in self.table_names:
            # yield self._dump_to_records(in_rows=self.in_dict, mapper_set=self.mapper.get(table_name), extra_data=extra_data)
            return self._dump_to_records(in_rows=self.in_dict, mapper_set=self.mapper.get(table_name), extra_data=extra_data)

        else:
            raise ValueError(f'{table_name} is not defined in mapper. We got {self.table_names}')

    def _dump_single_row(self, in_row: list, mapper_set: list, extra_data: dict=None, ignore_location_str: str=None):
        extra_data = {} if extra_data is None else extra_data
        
        output_row = {}
        first_column = next(iter(mapper_set)).column_name

        # for column, location in column_set.items():
        for mapperlocation in mapper_set:
            column = mapperlocation.column_name
            location = mapperlocation.location
            delimiter = mapperlocation.delimiter

            # Hack to remove unneeded location string as we now have no reference to it.
            if ignore_location_str is not None:
                # ignore_location_str = ignore_location_str #+ f'[]{mapperlocation.delimiter}'
                location = location.replace(ignore_location_str, '')

            # If we only need to pull a single element.
            try:
                location_elements = location.split(delimiter)

                if location_elements[0] == 'root' and len(location_elements) == 1:
                    output_row.update({column: in_row})

                current_object = in_row
                
                for single_location in location_elements:
                    # Ignore the root element
                    if single_location == 'root':
                        continue

                    # If we specify we want just the first element in a list eg: payments[0].get('key')
                    if re.match(self.re_check_list_specific_element, single_location):
                        location_name = re.search(self.re_list_location_name, single_location).group()
                        location_index = int(re.search(self.re_list_location_index, single_location).group())
                        try:
                            current_object = current_object.get(location_name)[location_index]
                        except IndexError:
                            print(f'Warning: indexerror {location_name}[{location_index}] does not exist in {location}. First column is {first_column}, data is {output_row.get(first_column)}')
                            if mapperlocation.fail_if_missing:
                                raise RequiredElementMissingError(f'Required element {location_name}[{location_index}] does not exist in {location}. First column is {first_column}, data is {output_row.get(first_column)}')
                            output_row.update({column: mapperlocation.coalesce_value})
                            break
                        
                    else:
                        if not hasattr(current_object, 'get') and type(current_object) == str and mapperlocation.attempt_json_serializing:
                            current_object = json.loads(current_object)
                            
                        current_object = current_object.get(single_location)
                        if current_object is None:
                            print(f'Warning: elementnotfound {single_location} does not exist in {location}. First column is {first_column}, data is {output_row.get(first_column)}')
                            if mapperlocation.fail_if_missing:
                                raise RequiredElementMissingError(f'Required element {single_location} does not exist in {location}. First column is {first_column}, data is {output_row.get(first_column)}')
                            # derp
                            output_row.update({column: mapperlocation.coalesce_value})
                            break
                    
                    output_row.update({column: current_object})

            except AttributeError:
                print(f'Warning: attributeerror {single_location} does not exist in {location}. First column is {first_column}, data is {output_row.get(first_column)}')
                if mapperlocation.fail_if_missing:
                    raise RequiredElementMissingError(f'Required element {single_location} does not exist in {location}. First column is {first_column}, data is {output_row.get(first_column)}')
                output_row.update({column: mapperlocation.coalesce_value})
                continue

        output_row.update(extra_data)
        
        return output_row

    def _dump_to_records(self, in_rows, mapper_set, extra_data=None):
        if extra_data == None:
            extra_data = {}

        out_rows = []
        
        nested_list_mapper_set = []
        nested_list_base_location = set()

        single_mapper_set = []

        for mapper in mapper_set:
            if re.search(self.re_check_list_unlimited_element, mapper.location):
                nested_list_mapper_set.append(mapper)
                nested_list_base_location.add(re.match(self.re_check_list_base_location, mapper.location).group())
                nested_list_base_location_delimiter = mapper.delimiter
            else:
                single_mapper_set.append(mapper)

        if len(nested_list_base_location) > 1:
            raise AttributeError(f"This library does not currently supported multiple listed mappers in a single instance. Sorry. We found {nested_list_base_location}")

        nested_list_base_location = next(iter(nested_list_base_location))
        nested_list_base_location_elements = nested_list_base_location.split(nested_list_base_location_delimiter)
        nested_list_base_location = nested_list_base_location + f'[]{nested_list_base_location_delimiter}'

        for row in in_rows:
            output_row = self._dump_single_row(in_row=row, mapper_set=single_mapper_set, extra_data=extra_data)

            if len(nested_list_base_location) > 0:
                output_nested_rows = []
                nested_rows = row.copy()
                for element in nested_list_base_location_elements:
                    if element == 'root':
                        continue
                    else:
                        nested_rows = nested_rows.get(element, {})

                for nested_row in nested_rows:
                    output_nested_rows.append(self._dump_single_row(in_row=nested_row, mapper_set=nested_list_mapper_set, extra_data=output_row, ignore_location_str=nested_list_base_location))

                out_rows.extend(output_nested_rows)

            else:
                out_rows.append(output_row)


        return out_rows

# %%
mapper = {
    'realtime_trips': [
        MapperLocation(location='root::id', column_name='message_id'),
        MapperLocation(location='root::tripUpdate::trip::tripId', column_name='trip_id'),
        MapperLocation(location='root::tripUpdate::trip::startTime', column_name='start_time'),
        MapperLocation(location='root::tripUpdate::trip::startDate', column_name='start_date'),
        MapperLocation(location='root::tripUpdate::trip::routeId', column_name='route_id'),
        MapperLocation(location='root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId', column_name='train_id'),
        MapperLocation(location='root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned', column_name='is_assigned'),
        MapperLocation(location='root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction', column_name='direction'),
        MapperLocation(location='root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction', column_name='direction'),
        MapperLocation(location='root::tripUpdate::stopTimeUpdate[]::arrival::time', column_name='scheduled_train_arrival_time'),
        MapperLocation(location='root::tripUpdate::stopTimeUpdate[]::departure::time', column_name='scheduled_train_departure_time'),
        MapperLocation(location='root::tripUpdate::stopTimeUpdate[]::stopId', column_name='scheduled_train_stop_id'),
        MapperLocation(location='root::tripUpdate::stopTimeUpdate[]::[transit_realtime.nyct_stop_time_update]::scheduledTrack', column_name='scheduled_train_scheduled_track'),
        MapperLocation(location='root::tripUpdate::stopTimeUpdate[]::[transit_realtime.nyct_stop_time_update]::actualTrack', column_name='scheduled_train_actual_track'),
        
    ]
}

with open('in.json', 'r') as f:
    in_json = json.loads(f.read())

realtime_trips_root = in_json.get('messages')
print(f'Got {len(realtime_trips_root)} realtime trips')

rt = DictMapper(in_dict=realtime_trips_root, mapper=mapper)

realtime_trips_data = rt.get_records(table_name='realtime_trips')
# Out:
# Got 74 realtime trips
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000002N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000002N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000002N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000002N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000002N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000002N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000002N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000002N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000003N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000003N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000004N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000004N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000004N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000004N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000004N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000004N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000004N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000004N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000006N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000006N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000006N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000006N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000006N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000006N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000006N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000006N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000008N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000008N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000008N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000008N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000008N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000008N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000008N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000008N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000009N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000009N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000010N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000010N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000010N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000010N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000010N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000010N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000010N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000010N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000012N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000012N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000012N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000012N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000012N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000012N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000012N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000012N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000013N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000013N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000014N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000014N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000014N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000014N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000014N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000014N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000014N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000014N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000016N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000016N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000016N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000016N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000016N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000016N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000016N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000016N
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000017N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000017N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000017N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000018N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000018N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000018N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000018N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000018N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000018N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000018N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000018N
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000019N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000020N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000020N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000020N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000020N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000020N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000020N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000020N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000020N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000021N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000021N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000022N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000022N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000022N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000022N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000022N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000022N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000022N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000022N
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000023N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000023N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000023N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000024N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000024N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000024N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000024N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000024N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000024N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000024N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000024N
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000025N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000026N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000026N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000026N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000026N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000026N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000026N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000026N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000026N
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000027N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000027N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000027N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000028N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000028N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000028N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000028N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000028N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000028N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000028N
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000028N
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000001Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000001Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000002Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000002Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000002Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000002Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000002Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000002Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000002Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000002Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000003Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000003Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000004Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000004Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000004Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000004Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000004Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000004Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000004Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000004Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000005Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000005Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000006Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000006Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000006Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000006Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000006Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000006Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000006Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000006Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000007Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000007Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000008Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000008Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000008Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000008Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000008Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000008Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000008Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000008Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000009Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000009Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000010Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000010Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000010Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000010Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000010Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000010Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000010Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000010Q
# Warning: elementnotfound scheduledTrack does not exist in [transit_realtime.nyct_stop_time_update]::scheduledTrack. First column is scheduled_train_arrival_time, data is 1701939700
# Warning: elementnotfound actualTrack does not exist in [transit_realtime.nyct_stop_time_update]::actualTrack. First column is scheduled_train_arrival_time, data is 1701939700
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000012Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000012Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000012Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000012Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000012Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000012Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000012Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000012Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000013Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000013Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000014Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000014Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000014Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000014Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000014Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000014Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000014Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000014Q
# Warning: elementnotfound scheduledTrack does not exist in [transit_realtime.nyct_stop_time_update]::scheduledTrack. First column is scheduled_train_arrival_time, data is 1701940795
# Warning: elementnotfound actualTrack does not exist in [transit_realtime.nyct_stop_time_update]::actualTrack. First column is scheduled_train_arrival_time, data is 1701940795
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000016Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000016Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000016Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000016Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000016Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000016Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000016Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000016Q
# Warning: elementnotfound scheduledTrack does not exist in [transit_realtime.nyct_stop_time_update]::scheduledTrack. First column is scheduled_train_arrival_time, data is 1701941524
# Warning: elementnotfound actualTrack does not exist in [transit_realtime.nyct_stop_time_update]::actualTrack. First column is scheduled_train_arrival_time, data is 1701941524
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000018Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000018Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000018Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000018Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000018Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000018Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000018Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000018Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000019Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000019Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000020Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000020Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000020Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000020Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000020Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000020Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000020Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000020Q
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000021Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000021Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000021Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000022Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000022Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000022Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000022Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000022Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000022Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000022Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000022Q
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000023Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000024Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000024Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000024Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000024Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000024Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000024Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000024Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000024Q
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000025Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000025Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000025Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000026Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000026Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000026Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000026Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000026Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000026Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000026Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000026Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000028Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000028Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000028Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000028Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000028Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000028Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000028Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000028Q
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000029Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000030Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000030Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000030Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000030Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000030Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000030Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000030Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000030Q
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000031Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000032Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000032Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000032Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000032Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000032Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000032Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000032Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000032Q
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000033Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000033Q
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000033Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000034Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000034Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000034Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000034Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000034Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000034Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000034Q
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000034Q
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000001R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000002R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000002R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000002R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000002R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000002R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000002R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000002R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000002R
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000003R
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000003R
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000003R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000004R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000004R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000004R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000004R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000004R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000004R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000004R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000004R
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000005R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000006R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000006R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000006R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000006R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000006R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000006R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000006R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000006R
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000007R
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000007R
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000007R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000008R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000008R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000008R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000008R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000008R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000008R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000008R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000008R
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000009R
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000009R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000010R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000010R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000010R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000010R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000010R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000010R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000010R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000010R
# Warning: elementnotfound isAssigned does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000011R
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000011R
# Warning: elementnotfound direction does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000011R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::tripId. First column is message_id, data is 000012R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startTime. First column is message_id, data is 000012R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::startDate. First column is message_id, data is 000012R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::routeId. First column is message_id, data is 000012R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::trainId. First column is message_id, data is 000012R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::isAssigned. First column is message_id, data is 000012R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000012R
# Warning: elementnotfound tripUpdate does not exist in root::tripUpdate::trip::[transit_realtime.nyct_trip_descriptor]::direction. First column is message_id, data is 000012R

# %%
import pandas as pd

df = pd.DataFrame.from_records(realtime_trips_data)

display(df)
# Out:
#     scheduled_train_arrival_time scheduled_train_departure_time  \
# 0                     1701938910                     1701938910
# 1                     1701939165                     1701939165
# 2                     1701939645                     1701939645
# 3                     1701938900                     1701938900
# 4                     1701938910                     1701938910
# ..                           ...                            ...
# 865                   1701943800                     1701943800
# 866                   1701943890                     1701943890
# 867                   1701943980                     1701943980
# 868                   1701944130                     1701944130
# 869                   1701944220                     1701944220
#
#     scheduled_train_stop_id scheduled_train_scheduled_track  \
# 0                      N09S                              E1
# 1                      N10S                              E1
# 2                      D43S                              0B
# 3                      R05N                              G2
# 4                      R04N                              G2
# ..                      ...                             ...
# 865                    R30N                              B2
# 866                    R29N                              B2
# 867                    R28N                              B2
# 868                    R65N                              B2
# 869                    R27N                              BM
#
#     scheduled_train_actual_track message_id      trip_id start_time  \
# 0                             E1    000001N  013738_N..S   02:17:23
# 1                             E1    000001N  013738_N..S   02:17:23
# 2                             0B    000001N  013738_N..S   02:17:23
# 3                             G2    000003N  013300_N..N   02:13:00
# 4                             G2    000003N  013300_N..N   02:13:00
# ..                           ...        ...          ...        ...
# 865                           B2    000011R  028600_R..N   04:46:00
# 866                           B2    000011R  028600_R..N   04:46:00
# 867                           B2    000011R  028600_R..N   04:46:00
# 868                           B2    000011R  028600_R..N   04:46:00
# 869                           BM    000011R  028600_R..N   04:46:00
#
#     start_date route_id          train_id is_assigned direction
# 0     20231207        N  1N 0210+ DIT/STL        True     SOUTH
# 1     20231207        N  1N 0210+ DIT/STL        True     SOUTH
# 2     20231207        N  1N 0210+ DIT/STL        True     SOUTH
# 3     20231207        N   1N 0213 STL/DIT        True      None
# 4     20231207        N   1N 0213 STL/DIT        True      None
# ..         ...      ...               ...         ...       ...
# 865   20231207        R   1R 0446 95S/WHL        None      None
# 866   20231207        R   1R 0446 95S/WHL        None      None
# 867   20231207        R   1R 0446 95S/WHL        None      None
# 868   20231207        R   1R 0446 95S/WHL        None      None
# 869   20231207        R   1R 0446 95S/WHL        None      None
#
# [870 rows x 13 columns]

# %%
df.to_csv('blah.csv', index=False)
